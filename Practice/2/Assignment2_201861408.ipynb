# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('population.csv')
df
# Out:
#      Continent      Country  Year  Population  Yearly%Change  YearlyChange  \
# 0         Asia  Afghanistan  1955     8270991           1.30        103775
# 1         Asia  Afghanistan  1960     8996973           1.70        145196
# 2         Asia  Afghanistan  1965     9956320           2.05        191869
# 3         Asia  Afghanistan  1970    11173642           2.33        243464
# 4         Asia  Afghanistan  1975    12689160           2.58        303104
# ...        ...          ...   ...         ...            ...           ...
# 4225    Africa     Zimbabwe  2016    14030331           1.56        215702
# 4226    Africa     Zimbabwe  2017    14236595           1.47        206264
# 4227    Africa     Zimbabwe  2018    14438802           1.42        202207
# 4228    Africa     Zimbabwe  2019    14645468           1.43        206666
# 4229    Africa     Zimbabwe  2020    14862924           1.48        217456
#
#       MedianAge  UrbanPopulation
# 0          19.2           587818
# ...

# %% [markdown]
# # Answer 1

# %%
country_df = df[df['Country'] == 'Canada']
country_df
# Out:
#          Continent Country  Year  Population  Yearly%Change  YearlyChange  \
# 648  North America  Canada  1955    15673763           2.68        388072
# 649  North America  Canada  1960    17847405           2.63        434728
# 650  North America  Canada  1965    19627980           1.92        356115
# 651  North America  Canada  1970    21374326           1.72        349269
# 652  North America  Canada  1975    23059265           1.53        336988
# 653  North America  Canada  1980    24416886           1.15        271524
# 654  North America  Canada  1985    25744810           1.06        265585
# 655  North America  Canada  1990    27541319           1.36        359302
# 656  North America  Canada  1995    29164152           1.15        324567
# 657  North America  Canada  2000    30588383           0.96        284846
# 658  North America  Canada  2005    32164309           1.01        315185
# 659  North America  Canada  2010    34147564           1.20        396651
# ...

# %%
x = country_df['Year']
y = country_df['Population']
plt.xlabel('Year')
plt.ylabel('Population')
plt.title("Canada's Population Growth")
plt.yticks([1.5e7, 2.0e7, 2.5e7, 3.0e7, 3.5e7], ['15M', '20M', '25M', '30M', '35M'])
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Answer 2

# %%
df['Year'].unique()
# Out:
# array([1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005,
#        2010, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
year = 1955
percentage_list = []
while year <= 2010:
    urban_df = df[df['Year'] == year]
    global_population = urban_df['Population'].sum()
    urban_population = urban_df['UrbanPopulation'].sum()
    percentage = (urban_population / global_population) * 100
    percentage_list.append(percentage)
    year = year + 5
while year <= 2020:
    urban_df = df[df['Year'] == year]
    global_population = urban_df['Population'].sum()
    urban_population = urban_df['UrbanPopulation'].sum()
    percentage = (urban_population / global_population) * 100
    percentage_list.append(percentage)
    year = year + 1

# %%
x1 = [1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2016, 2017, 2018, 2019, 2020]
y1 = percentage_list
plt.xlabel('Year')
plt.ylabel('Urban Percentage')
plt.title('Percentage of Global Population living in Urban Areas')
plt.ylim(30,57.5)
plt.yticks([30, 35, 40, 45, 50, 55], ['30%', '35%', '40%', '45%', '50%', '55%'])
plt.plot(x1, y1)
plt.show()

# %% [markdown]
# # Answer 3

# %%
df['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania',
#        'Latin America and the Caribbean', 'North America'], dtype=object)

# %%
#fig = plt.Figure()
#ax = fig.axes([0,0,1,1])
fig, ax = plt.subplots(figsize=(8, 5))
continent = ['Africa', 'Asia', 'Europe', 'Latin America and the Caribbean', 'North America', 'Oceania']
i = 0

while i < len(continent):
    year = 1955
    population_list = []
    continent_df = df[df['Continent'] == continent[i]]
    while year <= 2010:
        population_df = continent_df[continent_df['Year'] == year]
        population = population_df['YearlyChange'].sum()
        population_list.append(population)
        year = year + 5
    while year <= 2020:
        population_df = continent_df[continent_df['Year'] == year]
        population = population_df['YearlyChange'].sum()
        population_list.append(population)
        year = year + 1
    ax.plot(x1, population_list, label = continent[i])
    i = i + 1

#plt.ylim(,6.5e7)
ax.set_xlabel('Year')
ax.set_ylabel('Yearly Population Change')
ax.set_title('Yearly Population Change by Continent')
ax.legend(loc = 'center', frameon = False)
fig.tight_layout()
plt.show()

# %% [markdown]
# # Answer 4

# %%
continent
# Out:
# ['Africa',
#  'Asia',
#  'Europe',
#  'Latin America and the Caribbean',
#  'North America',
#  'Oceania']

# %%
fig, ax = plt.subplots(figsize =(8,5))
year_range_df = df[(df['Year'] == 2019) | (df['Year'] == 2020)]
i = 0
while i < len(continent):
    median_and_percent_df = year_range_df[year_range_df['Continent'] == continent[i]]
    ax.scatter(median_and_percent_df['MedianAge'], median_and_percent_df['Yearly%Change'], label = continent[i])
    i = i + 1
ax.set_xlabel('Median Age')
ax.set_ylabel('Percent')
ax.set_title('Country Population Growths (2019 to 2020)')
ax.set_xlim(14,50)
ax.set_ylim(-2.9, 4.2)
ax.legend(loc = 'lower left', frameon = False)
fig.tight_layout()
plt.show()

# %% [markdown]
# # Answer 5

# %%
new_df = df[df['Year'] == 2020]
new_df['Population']
# Out:
# 17      38928346
# 35       2877797
# 53      43851044
# 71         55191
# 89         77265
#           ...
# 4157       11239
# 4175      597339
# 4193    29825964
# 4211    18383955
# 4229    14862924
# Name: Population, Length: 235, dtype: int64

# %%
final_df = new_df.nlargest(10, ['Population'])
final_df
# Out:
#                             Continent        Country  Year  Population  \
# 791                              Asia          China  2020  1439323776
# 1745                             Asia          India  2020  1380004385
# 4049                    North America  United States  2020   331002651
# 1763                             Asia      Indonesia  2020   273523615
# 2861                             Asia       Pakistan  2020   220892340
# 503   Latin America and the Caribbean         Brazil  2020   212559417
# 2735                           Africa        Nigeria  2020   206139589
# 305                              Asia     Bangladesh  2020   164689383
# 3077                           Europe         Russia  2020   145934462
# 2411  Latin America and the Caribbean         Mexico  2020   128932753
#
#       Yearly%Change  YearlyChange  MedianAge  UrbanPopulation
# 791            0.39       5540090       38.4        875075919
# 1745           0.99      13586631       28.4        483098640
# ...

# %%
fig, ax = plt.subplots(figsize = (12,6))
ax.barh(final_df['Country'], final_df['Population'], color = ['#3D59AB', '#FF6103', '#458B00', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan'])
ax.invert_yaxis()
ax.set_xticks([0e9, 0.2e9, 0.4e9, 0.6e9, 0.8e9, 1.0e9, 1.2e9, 1.4e9], ['0', '200 M', '400 M', '600 M', '800 M', '1 B', '1.2 B', '1.4 B'])
#ax.set_xticks([0e9, 0.2e9, 0.4e9, 0.6e9, 0.8e9, 1.0e9, 1.2e9, 1.4e9], rotation = 60)
#ax.set_xticklabels(['0', '200 M', '400 M', '600 M', '800 M', '1 B', '1.2 B', '1.4 B'])
ax.set_title('Top 10 Countries by Population (2020)')
fig.tight_layout()
plt.show()
