# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('olympic_athletes.csv')
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
df1 = df[(df['Sport'] == 'Gymnastics') | (df['Sport'] == 'Cycling') | (df['Sport'] == 'Basketball')]
df1
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 0            1                        A Dijiang   M  24.0   180.0    80.0
# 41          17          Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 42          17          Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 43          17          Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17          Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                              ...  ..   ...     ...     ...
# 271003  135515     Adriaan "Adrie" Zwartepoorte   M  19.0     NaN     NaN
# 271026  135530                   Philip Zwiener   M  23.0   202.0    98.0
# 271075  135552  Jan (Johann-) Zybert (Siebert-)   M  20.0     NaN     NaN
# 271101  135562                       Milan Zyka   M  24.0   173.0    68.0
# 271110  135568           Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
df1['Sport'].unique()
# Out:
# array(['Basketball', 'Gymnastics', 'Cycling'], dtype=object)

# %%
df1['Year'].unique()
# Out:
# array([1992, 1948, 1952, 1920, 2016, 1956, 1924, 2008, 2004, 2000, 1900,
#        1960, 1972, 1984, 1988, 1976, 1980, 1996, 2012, 1968, 1936, 1906,
#        1912, 1964, 1908, 1932, 1928, 1904, 1896], dtype=int64)

# %%
df1 = df1[df1['Year'] >= 2000]
df1
# Out:
#             ID                    Name Sex   Age  Height  Weight         Team  \
# 139         51       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain
# 140         51       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain
# 141         51       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain
# 142         51       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain
# 143         51       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain
# ...        ...                     ...  ..   ...     ...     ...          ...
# 270744  135402      Mindaugas ukauskas   M  28.0   201.0   100.0    Lithuania
# 270766  135411               Alex Zlle   M  32.0   185.0    72.0  Switzerland
# 270767  135411               Alex Zlle   M  32.0   185.0    72.0  Switzerland
# 271026  135530          Philip Zwiener   M  23.0   202.0    98.0      Germany
# 271110  135568  Olga Igorevna Zyuzkova   F  33.0   171.0    69.0      Belarus
#
# ...

# %%
df1['Year'].unique()
# Out:
# array([2016, 2008, 2004, 2000, 2012], dtype=int64)

# %%
df1.sort_values(by = ['Year'], ascending = True, inplace = True)
df1
# Out:
# C:\Users\sakif\AppData\Local\Temp\ipykernel_4380\3139478809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.sort_values(by = ['Year'], ascending = True, inplace = True)
#             ID                                 Name Sex   Age  Height  Weight  \
# 183739   92348           Ivan Leonidovich Pavlovsky   M  23.0   166.0    60.0
# 252879  126619      Jos Antonio Villanueva Trinidad   M  21.0   175.0    76.0
# 252880  126619      Jos Antonio Villanueva Trinidad   M  21.0   175.0    76.0
# 264870  132547                             Yang Wei   M  20.0   160.0    54.0
# 50077    25774  Dominique Margaux Dawes (-Thompson)   F  23.0   158.0    54.0
# ...        ...                                  ...  ..   ...     ...     ...
# ...

# %%
df1['Sport'].unique()
# Out:
# array(['Gymnastics', 'Cycling', 'Basketball'], dtype=object)

# %%
df1['Height'].describe()
# Out:
# count    9575.000000
# mean      170.667572
# std        14.365084
# min       133.000000
# 25%       161.000000
# 50%       169.000000
# 75%       180.000000
# max       226.000000
# Name: Height, dtype: float64

# %%
basketball = df1[df1['Sport'] == 'Basketball']
basketball['Name'].nunique()
# Out:
# 1074

# %%
df1['Name'].nunique()
# Out:
# 3519

# %%
df1.drop_duplicates(['Name'], inplace = True)
# Out:
# C:\Users\sakif\AppData\Local\Temp\ipykernel_4380\166515209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(['Name'], inplace = True)

# %%
df1['Name'].nunique()
# Out:
# 3519

# %%
df1
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 183739   92348           Ivan Leonidovich Pavlovsky   M  23.0   166.0    60.0
# 252879  126619      Jos Antonio Villanueva Trinidad   M  21.0   175.0    76.0
# 264870  132547                             Yang Wei   M  20.0   160.0    54.0
# 50077    25774  Dominique Margaux Dawes (-Thompson)   F  23.0   158.0    54.0
# 238042  119372                        Olha Teslenko   F  19.0   151.0    40.0
# ...        ...                                  ...  ..   ...     ...     ...
# 154204   77430                     Shannon McCurley   F  24.0   163.0    65.0
# 154538   77583             Courtney Louise McGregor   F  17.0   159.0    57.0
# 155915   78286                       Louis Meintjes   M  24.0   173.0    58.0
# 156325   78508         Angelina Romanovna Melnikova   F  16.0   151.0    44.0
# 271110  135568               Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
df1['Height'].mean()
# Out:
# 177.22196796338673

# %%
basketball_df = df1[df1['Sport'] == 'Basketball']
basketball = basketball_df['Height'].describe()

# %%
basketball
# Out:
# count    1073.000000
# mean      191.316869
# std        12.268006
# min       161.000000
# 25%       182.000000
# 50%       191.000000
# 75%       201.000000
# max       226.000000
# Name: Height, dtype: float64

# %%
cycling_df = df1[df1['Sport'] == 'Cycling']
cycling = cycling_df['Height'].describe()

# %%
cycling
# Out:
# count    1691.000000
# mean      175.725015
# std         8.264816
# min       149.000000
# 25%       170.000000
# 50%       176.000000
# 75%       181.000000
# max       201.000000
# Name: Height, dtype: float64

# %%
gymnastics_df = df1[df1['Sport'] == 'Gymnastics']
gymnastics = gymnastics_df['Height'].describe()

# %%
gymnastics
# Out:
# count    732.000000
# mean     160.019126
# std        8.875313
# min      133.000000
# 25%      154.000000
# 50%      161.000000
# 75%      167.000000
# max      184.000000
# Name: Height, dtype: float64

# %%
data1 = basketball_df['Height']
cycling_df = cycling_df.dropna()
data2 = cycling_df['Height']
gymnastics_df = gymnastics_df.dropna()
data3 = gymnastics_df['Height']
data = [data3, data2, data1]
data
# Out:
# [52527     166.0
#  46826     168.0
#  140767    153.0
#  250254    168.0
#  193509    150.0
#  246722    163.0
#  5829      158.0
#  235719    163.0
#  169665    174.0
#  183224    152.0
#  154042    167.0
#  186504    152.0
#  245787    170.0
#  92623     142.0
#  84500     146.0
#  167905    165.0
#  109703    145.0
#  223671    184.0
#  140846    160.0
#  236058    166.0
#  196046    157.0
#  58015     157.0
#  259828    167.0
#  267707    156.0
#  20123     178.0
#  150079    160.0
#  137845    170.0
#  182832    161.0
#  166652    162.0
#  123386    150.0
#  235867    148.0
#  94892     152.0
#  21758     143.0
#  199788    155.0
#  187216    164.0
#  226616    156.0
#  140788    162.0
#  122274    157.0
#  Name: Height, dtype: float64,
#  252810    172.0
#  129250    174.0
#  253127    177.0
#  52112     172.0
#  39828     175.0
#            ...
#  133804    173.0
#  142002    170.0
#  149091    170.0
#  145963    187.0
#  146984    173.0
# ...

# %%
colors = ['purple', 'green', 'blue']

from matplotlib.patches import PathPatch
fig, ax = plt.subplots()
ax.violinplot(data, vert = False, showextrema = False, showmedians = True)


for i, violin in enumerate(ax.collections):
    if i == 0:
        violin.set_facecolor('purple')
        
    elif i == 1:
        violin.set_facecolor('green')
        
    else:
        violin.set_facecolor('blue')
        



ax.set_xlim(130,230)
ax.set_yticks([3.0, 2.0, 1.0], ['Basketball', 'Cycling', 'Gymnastics'])
ax.set_xlabel('Height (cm)')
ax.set_title('Height Distributions (2000 - 2016 Olympics)')
plt.show()

# %%
colors = ['purple', 'red', 'blue']
median_colors = ['white', 'white', 'white']

# Create the violin plot
fig, ax = plt.subplots()
ax.violinplot(data, vert=False, showmedians=True)

# Set the facecolor and median color for each violin
for i, violin in enumerate(ax.collections):
    violin.set_facecolor(colors[i])
    median = violin.get_paths()[0]
    median_patch = plt.PathPatch(median, edgecolor=median_colors[i], lw=2)
    ax.add_patch(median_patch)

# Set the x limits, y ticks, and axis labels for the plot
ax.set_xlim(-5, 5)
ax.set_yticks([1, 2, 3])
ax.set_yticklabels(['violin 1', 'violin 2', 'violin 3'])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Horizontal Violin Plot with Different Median Colors')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [74], line 12
#      10     violin.set_facecolor(colors[i])
#      11     median = violin.get_paths()[0]
# ---> 12     median_patch = plt.PathPatch(median, edgecolor=median_colors[i], lw=2)
#      13     ax.add_patch(median_patch)
#      15 # Set the x limits, y ticks, and axis labels for the plot
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'PathPatch'

# %%
a = data1.isnull()
a.value_counts()
# Out:
# False    1073
# Name: Height, dtype: int64

# %%
b = data2.isnull()
b.value_counts()
# Out:
# False    149
# Name: Height, dtype: int64

# %%
c = data3.isnull()
c.value_counts()
# Out:
# False    38
# Name: Height, dtype: int64

# %% [markdown]
# # new 2

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df['Season'].unique()
# Out:
# array(['Summer', 'Winter'], dtype=object)

# %%
new_df = df[df['Season'] == 'Summer']
new_df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
new_df['Season'].unique()
# Out:
# array(['Summer'], dtype=object)

# %%
new_df['Year'].unique()
# Out:
# array([1992, 2012, 1920, 1900, 1932, 1952, 2000, 1996, 1912, 1924, 1948,
#        2008, 2016, 2004, 1984, 1968, 1972, 1988, 1936, 1956, 1960, 1928,
#        1976, 1980, 1964, 1906, 1904, 1908, 1896], dtype=int64)

# %%
year = [1992, 2012, 1920, 1900, 1932, 1952, 2000, 1996, 1912, 1924, 1948,
       2008, 2016, 2004, 1984, 1968, 1972, 1988, 1936, 1956, 1960, 1928,
       1976, 1980, 1964, 1906, 1904, 1908, 1896]
year.sort()

# %%
year
# Out:
# [1896,
#  1900,
#  1904,
#  1906,
#  1908,
#  1912,
#  1920,
#  1924,
#  1928,
#  1932,
#  1936,
#  1948,
#  1952,
#  1956,
#  1960,
#  1964,
#  1968,
#  1972,
#  1976,
#  1980,
#  1984,
#  1988,
#  1992,
#  1996,
#  2000,
#  2004,
#  2008,
#  2012,
#  2016]

# %%
new_df['Sex'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
male_df = new_df[new_df['Sex'] == 'M']
male_df
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 0            1                       A Dijiang   M  24.0   180.0    80.0
# 1            2                        A Lamusi   M  23.0   170.0    60.0
# 2            3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 29          10  Einar Ferdinand "Einari" Aalto   M  26.0     NaN     NaN
# ...        ...                             ...  ..   ...     ...     ...
# 271105  135565        Fernando scar Zylberberg   M  23.0   168.0    76.0
# 271106  135565        Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566      James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567    Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567    Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
#
#                   Team  NOC        Games  Year  Season       City       Sport  \
# ...

# %%
male_df['Sex'].unique()
# Out:
# array(['M'], dtype=object)

# %%
male_df = male_df.drop(columns = ['ID', 'Sex', 'Age', 'Weight', 'Team', 'NOC', 'Games', 'Season', 'City', 'Sport', 'Event', 'Medal'])
male_df
# Out:
#                                   Name  Height  Year
# 0                            A Dijiang   180.0  1992
# 1                             A Lamusi   170.0  2012
# 2                  Gunnar Nielsen Aaby     NaN  1920
# 3                 Edgar Lindenau Aabye     NaN  1900
# 29      Einar Ferdinand "Einari" Aalto     NaN  1952
# ...                                ...     ...   ...
# 271105        Fernando scar Zylberberg   168.0  2000
# 271106        Fernando scar Zylberberg   168.0  2004
# 271107      James Francis "Jim" Zylker   175.0  1972
# 271108    Aleksandr Viktorovich Zyuzin   183.0  2000
# 271109    Aleksandr Viktorovich Zyuzin   183.0  2004
#
# [163109 rows x 3 columns]

# %%
male_df = male_df.dropna()
male_df
# Out:
#                                 Name  Height  Year
# 0                          A Dijiang   180.0  1992
# 1                           A Lamusi   170.0  2012
# 31                 Jyri Tapani Aalto   172.0  2000
# 41           Paavo Johannes Aaltonen   175.0  1948
# 42           Paavo Johannes Aaltonen   175.0  1948
# ...                              ...     ...   ...
# 271105      Fernando scar Zylberberg   168.0  2000
# 271106      Fernando scar Zylberberg   168.0  2004
# 271107    James Francis "Jim" Zylker   175.0  1972
# 271108  Aleksandr Viktorovich Zyuzin   183.0  2000
# 271109  Aleksandr Viktorovich Zyuzin   183.0  2004
#
# [116839 rows x 3 columns]

# %%
female_df = new_df[new_df['Sex'] == 'F']
female_df
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 26           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 32          13                   Minna Maarit Aalto   F  30.0   159.0    55.5
# 33          13                   Minna Maarit Aalto   F  34.0   159.0    55.5
# 79          21            Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271099  135560                    Stavroula Zygouri   F  36.0   171.0    63.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
# 271110  135568               Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
female_df['Sex'].unique()
# Out:
# array(['F'], dtype=object)

# %%
female_df = female_df.drop(columns = ['ID', 'Sex', 'Age', 'Weight', 'Team', 'NOC', 'Games', 'Season', 'City', 'Sport', 'Event', 'Medal'])
female_df
# Out:
#                                        Name  Height  Year
# 26       Cornelia "Cor" Aalten (-Strannood)   168.0  1932
# 27       Cornelia "Cor" Aalten (-Strannood)   168.0  1932
# 32                       Minna Maarit Aalto   159.0  1996
# 33                       Minna Maarit Aalto   159.0  2000
# 79                Ragnhild Margrethe Aamodt   163.0  2008
# ...                                     ...     ...   ...
# 271080  Galina Ivanovna Zybina (-Fyodorova)   168.0  1964
# 271099                    Stavroula Zygouri   171.0  2004
# 271102            Olesya Nikolayevna Zykina   171.0  2000
# 271103            Olesya Nikolayevna Zykina   171.0  2004
# 271110               Olga Igorevna Zyuzkova   171.0  2016
#
# [59443 rows x 3 columns]

# %%
female_df = female_df.dropna()
female_df
# Out:
#                                        Name  Height  Year
# 26       Cornelia "Cor" Aalten (-Strannood)   168.0  1932
# 27       Cornelia "Cor" Aalten (-Strannood)   168.0  1932
# 32                       Minna Maarit Aalto   159.0  1996
# 33                       Minna Maarit Aalto   159.0  2000
# 79                Ragnhild Margrethe Aamodt   163.0  2008
# ...                                     ...     ...   ...
# 271080  Galina Ivanovna Zybina (-Fyodorova)   168.0  1964
# 271099                    Stavroula Zygouri   171.0  2004
# 271102            Olesya Nikolayevna Zykina   171.0  2000
# 271103            Olesya Nikolayevna Zykina   171.0  2004
# 271110               Olga Igorevna Zyuzkova   171.0  2016
#
# [53856 rows x 3 columns]

# %%
i = 0
avg_male_height_list = []
avg_female_height_list = []

male_upper_std_list = []
male_lower_std_list = []


female_upper_std_list = []
female_lower_std_list = []
while i < len(year):
    new_male_df = male_df[male_df['Year'] == year[i]]
    new_male_df = new_male_df.drop_duplicates(['Name'])
    avg_male_height = new_male_df['Height'].mean()
    avg_male_std = new_male_df['Height'].std()
    avg_male_height_list.append(avg_male_height)
    male_upper = avg_male_height + avg_male_std
    male_lower = avg_male_height - avg_male_std
    male_upper_std_list.append(male_upper)
    male_lower_std_list.append(male_lower)
    
    
    new_female_df = female_df[female_df['Year'] == year[i]]
    new_female_df = new_female_df.drop_duplicates(['Name'])
    avg_female_height = new_female_df['Height'].mean()
    avg_female_std = new_female_df['Height'].std()
    avg_female_height_list.append(avg_female_height)
    female_upper = avg_female_height + avg_female_std
    female_lower = avg_female_height - avg_female_std
    female_upper_std_list.append(female_upper)
    female_lower_std_list.append(female_lower)
    i = i + 1

# %%
avg_male_height_list
# Out:
# [174.85714285714286,
#  175.1153846153846,
#  175.82558139534885,
#  177.36263736263737,
#  176.61943319838056,
#  177.30517711171663,
#  176.35377358490567,
#  176.37056737588654,
#  176.63090909090909,
#  175.23700305810397,
#  177.6096866096866,
#  178.62822458270105,
#  178.41537053979872,
#  177.9121568627451,
#  176.39776462853385,
#  176.94645779752162,
#  177.4843316989981,
#  178.2115710892433,
#  178.86097297297297,
#  179.26972849530577,
#  179.3393988959313,
#  179.78483333333332,
#  180.85203890759448,
#  181.0922583909597,
#  181.51746960135446,
#  181.80696964830577,
#  182.00630150266602,
#  182.40319777546054,
#  182.15115894039735]

# %%
avg_female_height_list
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  161.8,
#  162.65,
#  168.50943396226415,
#  167.30769230769232,
#  167.14473684210526,
#  168.1829268292683,
#  166.58333333333334,
#  166.30731707317074,
#  165.66666666666666,
#  166.45277361319341,
#  167.20667522464697,
#  167.32456140350877,
#  169.5691446842526,
#  169.9326660600546,
#  169.3661697990927,
#  169.6497461928934,
#  170.0453089244851,
#  169.99800332778702,
#  170.12803970223325,
#  170.11469282877832,
#  170.35833333333332,
#  170.32919930374237,
#  170.02696719661904]

# %%
fig, ax = plt.subplots(figsize = (7,5))
x = year
y1 = avg_male_height_list
y2 = avg_female_height_list

m_up = male_upper_std_list
m_low = male_lower_std_list

f_up = female_upper_std_list
f_low = female_lower_std_list


ax.plot(x, y1, color = 'blue', label = 'Male')
ax.plot(x, y2, color = 'red', label = 'Female')
#ax.set_xlim(1890,2022)
ax.set_ylim(140,200)
ax.set_xlabel('Year')
ax.set_ylabel('Height (cm)')
ax.set_title('Average Olympian Height (+/- std dev) in the Summer Olympics')

plt.fill_between(x, m_up, m_low, alpha = 0.2)
plt.fill_between(x, f_up, f_low, alpha = 0.2)
plt.legend(loc = 'lower left')
plt.show()

# %% [markdown]
# # 3

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df['Medal'].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
df['Medal'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 271116 entries, 0 to 271115
# Series name: Medal
# Non-Null Count  Dtype
# --------------  -----
# 39783 non-null  object
# dtypes: object(1)
# memory usage: 2.1+ MB

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
medal_df = df.drop(columns = ['ID', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
       'Year', 'Season', 'City', 'Sport', 'Event'])
medal_df
# Out:
#                             Name Medal
# 0                      A Dijiang   NaN
# 1                       A Lamusi   NaN
# 2            Gunnar Nielsen Aaby   NaN
# 3           Edgar Lindenau Aabye  Gold
# 4       Christine Jacoba Aaftink   NaN
# ...                          ...   ...
# 271111                Andrzej ya   NaN
# 271112                  Piotr ya   NaN
# 271113                  Piotr ya   NaN
# 271114        Tomasz Ireneusz ya   NaN
# 271115        Tomasz Ireneusz ya   NaN
#
# [271116 rows x 2 columns]

# %%
medal_df = medal_df.dropna()

# %%
medal_df
# Out:
#                                        Name   Medal
# 3                      Edgar Lindenau Aabye    Gold
# 37                     Arvo Ossian Aaltonen  Bronze
# 38                     Arvo Ossian Aaltonen  Bronze
# 40                 Juhamatti Tapio Aaltonen  Bronze
# 41                  Paavo Johannes Aaltonen  Bronze
# ...                                     ...     ...
# 271078  Galina Ivanovna Zybina (-Fyodorova)  Silver
# 271080  Galina Ivanovna Zybina (-Fyodorova)  Bronze
# 271082                         Bogusaw Zych  Bronze
# 271102            Olesya Nikolayevna Zykina  Bronze
# 271103            Olesya Nikolayevna Zykina  Silver
#
# [39783 rows x 2 columns]
