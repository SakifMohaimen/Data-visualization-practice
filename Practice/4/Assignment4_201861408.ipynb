# %%
import pandas as pd
import matplotlib. pyplot as plt
import seaborn as sns

df_p = pd.read_csv('population.csv')
df_p
# Out:
#      Continent      Country  Year  Population  Yearly%Change  YearlyChange  \
# 0         Asia  Afghanistan  1955     8270991           1.30        103775
# 1         Asia  Afghanistan  1960     8996973           1.70        145196
# 2         Asia  Afghanistan  1965     9956320           2.05        191869
# 3         Asia  Afghanistan  1970    11173642           2.33        243464
# 4         Asia  Afghanistan  1975    12689160           2.58        303104
# ...        ...          ...   ...         ...            ...           ...
# 4225    Africa     Zimbabwe  2016    14030331           1.56        215702
# 4226    Africa     Zimbabwe  2017    14236595           1.47        206264
# 4227    Africa     Zimbabwe  2018    14438802           1.42        202207
# 4228    Africa     Zimbabwe  2019    14645468           1.43        206666
# 4229    Africa     Zimbabwe  2020    14862924           1.48        217456
#
#       MedianAge  UrbanPopulation
# 0          19.2           587818
# ...

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4230 entries, 0 to 4229
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Continent        4230 non-null   object
#  1   Country          4230 non-null   object
#  2   Year             4230 non-null   int64
#  3   Population       4230 non-null   int64
#  4   Yearly%Change    4230 non-null   float64
#  5   YearlyChange     4230 non-null   int64
#  6   MedianAge        4230 non-null   float64
#  7   UrbanPopulation  4230 non-null   int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 264.5+ KB

# %%
df_p['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania',
#        'Latin America and the Caribbean', 'North America'], dtype=object)

# %%
df_p.sort_values(by = 'Continent', inplace = True)
df_p
# Out:
#      Continent                   Country  Year  Population  Yearly%Change  \
# 2114    Africa                     Libya  1995     4948798           2.21
# 2093    Africa                   Liberia  1980     1853001           2.97
# 2092    Africa                   Liberia  1975     1600452           2.70
# 2091    Africa                   Liberia  1970     1400730           2.38
# 2090    Africa                   Liberia  1965     1245102           2.16
# ...        ...                       ...   ...         ...            ...
# 2805   Oceania  Northern Mariana Islands  2018       56882           0.57
# 2804   Oceania  Northern Mariana Islands  2017       56562           0.67
# 2803   Oceania  Northern Mariana Islands  2016       56188           0.73
# 2737   Oceania                      Niue  1960        4826           0.56
# 3238   Oceania                     Samoa  2019      197097           0.49
#
#       YearlyChange  MedianAge  UrbanPopulation
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax = sns.lineplot(x = 'Year', y = 'YearlyChange', data = df_p, hue = 'Continent', ci = None, legend = True)
ax.legend(loc = 'center', frameon = False)
#ax.set_ylim(0,6.5e7)
ax.set_yticks([0e6, 0.2e6, 0.4e6, 0.6e6, 0.8e6, 1.0e6, 1.2e6], ['0', '1', '2', '3', '4', '5', '6'])
ax.set_xlabel('Year')
ax.set_ylabel('Yearly Population Change')
ax.set_title('Yearly Population Change by Continent')
plt.show()

# %%
n = df_p[df_p['Continent'] == 'North America']
n['Year'].unique()
# Out:
# array([2017, 2016, 2018, 2019, 1960, 1965, 1970, 1975, 1980, 1985, 1990,
#        1995, 2015, 2000, 2010, 2020, 2005, 1955], dtype=int64)

# %%
year = [2017, 2016, 2018, 2019, 1960, 1965, 1970, 1975, 1980, 1985, 1990,
       1995, 2015, 2000, 2010, 2020, 2005, 1955]
year.sort()
year
# Out:
# [1955,
#  1960,
#  1965,
#  1970,
#  1975,
#  1980,
#  1985,
#  1990,
#  1995,
#  2000,
#  2005,
#  2010,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020]

# %%
i = 0
sum1 = 0
sumL = []
while i < len(year):
    north = n[n['Year'] == year[i]]
    sum1 = north['YearlyChange'].sum()
    sumL.append(sum1)
    i = i + 1
sumL
# Out:
# [2965606,
#  3443763,
#  2961019,
#  2307527,
#  2251983,
#  2351218,
#  2471323,
#  2684756,
#  2933863,
#  3594858,
#  2972300,
#  3200189,
#  2748818,
#  2493654,
#  2417657,
#  2353760,
#  2304999,
#  2268634]

# %% [markdown]
# # 2

# %%
olympic_df = pd.read_csv('olympic_athletes.csv')
olympic_df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
olympic_df['Season'].unique()
# Out:
# array(['Summer', 'Winter'], dtype=object)

# %%
olympic_df = olympic_df[olympic_df['Season'] == 'Summer']
olympic_df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
olympic_df = olympic_df.drop(columns = ['ID', 'Age', 'Weight', 'Team', 'NOC', 'Games', 'Season', 'City', 'Sport', 'Event', 'Medal'])

# %%
olympic_df.sort_values(by = 'Year', inplace = True)

# %%
olympic_df.dropna()
# Out:
#                                  Name Sex  Height  Year
# 116776      Alexandros Khalkokondylis   M   171.0  1896
# 116777      Alexandros Khalkokondylis   M   171.0  1896
# 131869  Francis Adonijah "Frank" Lane   M   170.0  1896
# 63071               Launceston Elliot   M   188.0  1896
# 63070               Launceston Elliot   M   188.0  1896
# ...                               ...  ..     ...   ...
# 31639                         Kim Bui   F   155.0  2016
# 31640                         Kim Bui   F   155.0  2016
# 249024             Seppe Van Holsbeke   M   193.0  2016
# 112345             Chase Tyler Kalisz   M   193.0  2016
# 271110         Olga Igorevna Zyuzkova   F   171.0  2016
#
# [170695 rows x 4 columns]

# %%
olympic_df = olympic_df.drop_duplicates(subset = ['Name', 'Year'], keep = 'first')
olympic_df
# Out:
#                              Name Sex  Height  Year
# 201803    George Stuart Robertson   M     NaN  1896
# 123038           Georgios Koletis   M     NaN  1896
# 116776  Alexandros Khalkokondylis   M   171.0  1896
# 247338         Georgios Valakakis   M     NaN  1896
# 227297             Spyridon Stais   M     NaN  1896
# ...                           ...  ..     ...   ...
# 196559    Santiago Ramrez Morales   M   180.0  2016
# 31638                     Kim Bui   F   155.0  2016
# 249024         Seppe Van Holsbeke   M   193.0  2016
# 112345         Chase Tyler Kalisz   M   193.0  2016
# 271110     Olga Igorevna Zyuzkova   F   171.0  2016
#
# [158711 rows x 4 columns]

# %%
olympic_df.dropna(inplace = True)

# %%
olympic_df
# Out:
#                                  Name Sex  Height  Year
# 116776      Alexandros Khalkokondylis   M   171.0  1896
# 131869  Francis Adonijah "Frank" Lane   M   170.0  1896
# 63071               Launceston Elliot   M   188.0  1896
# 56762             Kurt Wilhelm Doerry   M   179.0  1896
# 53221           Dimitrios Deligiannis   M   185.0  1896
# ...                               ...  ..     ...   ...
# 196559        Santiago Ramrez Morales   M   180.0  2016
# 31638                         Kim Bui   F   155.0  2016
# 249024             Seppe Van Holsbeke   M   193.0  2016
# 112345             Chase Tyler Kalisz   M   193.0  2016
# 271110         Olga Igorevna Zyuzkova   F   171.0  2016
#
# [125061 rows x 4 columns]

# %%
df_avg_height = olympic_df.groupby(['Year', 'Sex'])['Height'].agg(['mean', 'std']).reset_index()
#df_avg_height['std_up'] = df_avg_height['mean'] + df_avg_height['std']
#df_avg_height['std_low'] = df_avg_height['mean'] - df_avg_height['std']
#m = df_avg_height[df_avg_height['Sex'] == 'M']
#f = df_avg_height[df_avg_height['Sex'] == 'F']
df_avg_height
# Out:
#     Year Sex        mean        std
# 0   1896   M  174.857143  10.189415
# 1   1900   M  175.115385   8.243010
# 2   1904   M  175.825581   7.976719
# 3   1906   M  177.362637   7.199562
# 4   1908   M  176.619433   7.567643
# 5   1912   M  177.305177   7.271439
# 6   1920   F  161.800000   8.470116
# 7   1920   M  176.353774   7.555458
# 8   1924   F  162.650000   8.462145
# 9   1924   M  176.370567   7.527516
# 10  1928   F  168.509434   6.485554
# 11  1928   M  176.630909   8.253064
# 12  1932   F  167.307692   6.049078
# 13  1932   M  175.237003   8.567386
# 14  1936   F  167.144737   6.898703
# 15  1936   M  177.609687   8.270831
# 16  1948   F  168.182927   5.784458
# 17  1948   M  178.628225   8.059422
# 18  1952   F  166.583333   6.386191
# 19  1952   M  178.415371   8.361423
# 20  1956   F  166.307317   6.692709
# 21  1956   M  177.912157   8.656091
# 22  1960   F  165.666667   7.001997
# 23  1960   M  176.397107   8.430317
# 24  1964   F  166.452774   7.154795
# ...

# %%
colours = ['blue', 'red']
fig, ax = plt.subplots(figsize = (7,5))
ax = sns.lineplot(data=df_avg_height, x='Year', y='mean', hue='Sex', ci = 'sd', palette = colours, legend = True)
ax.set_title('Average Olympian Height (+/- std dev) in the Summer Olympics')
ax.set_ylabel('Height (cm)')
ax.set_ylim(140,200)
#sns.set(style="darkgrid")
plt.legend(loc = 'lower left')
plt.show()

# %% [markdown]
# # 3

# %%
game_df = pd.read_csv('game_consoles.csv')
game_df = game_df.drop(columns = ['Type', 'Release'])
game_df
# Out:
#                  Console    Company  Units_sold
# 0          PlayStation 2       Sony   155000000
# 1            Nintendo DS   Nintendo   154002000
# 2        Nintendo Switch   Nintendo   122550000
# 3               Game Boy   Nintendo   118690000
# 4          PlayStation 4       Sony   117200000
# 5            PlayStation       Sony   102490000
# 6                    Wii   Nintendo   101630000
# 7          PlayStation 3       Sony    87400000
# 8               Xbox 360  Microsoft    84000000
# 9   PlayStation Portable       Sony    82000000
# 10      Game Boy Advance   Nintendo    81510000
# 11          Nintendo 3DS   Nintendo    75940000
# 12                   NES   Nintendo    61910000
# 13              Xbox One  Microsoft    58500000
# 14                  SNES   Nintendo    49100000
# 15           Nintendo 64   Nintendo    32930000
# 16         PlayStation 5       Sony    32100000
# 17                  Xbox  Microsoft    24000000
# 18              GameCube   Nintendo    21740000
# ...

# %%
group = game_df.groupby(['Company', 'Console'])


inner_colors = ['#156EAF', '#DB2018', '#56B45B']
outer_colors = ['#5599CC', '#EA6727', '#83C143']


fig, ax = plt.subplots(figsize=(10, 10))


sizes = group['Units_sold'].sum()

ax.pie(sizes, labels=sizes.index.get_level_values(1), colors=outer_colors, startangle=343,
       wedgeprops=dict(width=0.4, edgecolor='w'))
plt.title('Best Selling Video Game Consoles')
plt.show()
